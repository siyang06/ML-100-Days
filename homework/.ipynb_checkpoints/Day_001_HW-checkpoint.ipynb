# %% [markdown]
# ### 作業1
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
#
#     - 選擇的資料為[“Google Analytics Cusotmer Revenue Prediction”](https://www.kaggle.com/c/ga-customer-revenue-prediction)的資料，Google Analytics可以收集到訪客在網站上的很豐富的瀏覽行為，透過分析這些真實的線上行為資料來預測未來客戶的行為，對制定更精準的行銷計劃有很重要的意義。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
#     - 販售Google紀念品的線上商店[Google Merchandise Store](https://googlemerchandisestore.com/)，有安裝Google Analytics的追蹤碼，可以追蹤到訪客從什麼管道來到這個網站、以及在網站上的瀏覽、點擊、停留和購物等等的行為。
#
# 3. 蒐集而來的資料型態為何
#
#     - 資料存放在csv和json檔案中，為結構化的資料，裡面有數值型的欄位例如pageviews, visits, hits等，有日期的欄位，也有很多類別型的欄位如city, channelGrouping, browser等等。
#
# 4. 這組資料想解決的問題如何評估
#
#     - 這組資料想要解決的問題是預測每位訪客在未來一段時間的營收，這會是一個回歸的問題，可以透過計算MAE, RMSE, MAPE等來評估模型的準確性。

# %% [markdown]
# ### 作業2
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
#     - 核心問題為提升車隊的業績，可以透過讓更多的乘客來搭車，以及讓更多的司機可以加入到車隊這兩種方式來提升業績。假設可以透過投放廣告和的方式來讓更多人知道這個自由載客的車隊
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
#     - 可以整理現有的內部營運資料和蒐集/爬取一些外部的資料
#
# 3. 蒐集而來的資料型態為何
#
#     - 可能會有結構化的訂單資料和非結構化的乘客評價資料
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
#     - 可以透過A/B測試的方式來驗證廣告的有效性

# %% [markdown]
# ### 作業3
#
# 請點選檢視範例依照 Day_001_example_of_metrics.ipynb 完成 Mean Squared Error 的函式
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mse: MSE
    """
    mse = MSE = sum((y - yp)**2)/len(y)
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 238.887
# The Mean absolute error is 12.053
